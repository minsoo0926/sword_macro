# %% [markdown]
# ## Data Parsing

# %%
import pandas as pd
import re

def parse_data(file_path):
    df = pd.read_csv(file_path)
    # df = df[df['User'] == '플레이봇']
    new_df = pd.DataFrame(columns=["User", "Result", "Level", "Sword_name", "Message"])
    for _, row in df.iterrows():
        message = row["Message"]
        name_pattern = re.findall(r'@(\w+)', message)
        enhance_pattern = re.findall(r'강화 (\w+)', message)
        level_pattern = re.findall(r'\+(\d+)', message)
        level = level_pattern[0] if level_pattern else None
        sword_name_pattern = re.findall(r'\[\+\d+\]\s([\w\s]+)', message)
        sword_name = sword_name_pattern[0] if sword_name_pattern else None
        
        if name_pattern and enhance_pattern:
            name = name_pattern[0]
            enhance = enhance_pattern[0]
        else:
            continue

        if enhance not in ['유지', '성공', '파괴']:
            continue
        new_df.loc[len(new_df)] = {'User': name, 'Result': enhance, 'Level': level, 'Sword_name': sword_name, 'Message': message}
    
    new_file_path = file_path.split('.')[0] + '_parsed.csv'
    new_df.to_csv(new_file_path, index=False)
    return new_df

# %%
datas = ['data/1.csv', 'data/2.csv', 'data/3.csv', 'data/4.csv']
for data in datas:
    parse_data(data)

# %% [markdown]
# ## Calculate probs

# %%
from constants import *

parsed_datas = ['data/1_parsed.csv', 'data/2_parsed.csv', 'data/3_parsed.csv', 'data/4_parsed.csv']
data = pd.concat([pd.read_csv(file) for file in parsed_datas], ignore_index=True)
data['Level'] = pd.to_numeric(data['Level'], errors='coerce')

name_datas = {}

for index, row in data.iterrows():
    name = row['User']
    if name not in name_datas:
        name_datas[name] = pd.DataFrame(columns=row.index)
    name_datas[name].loc[len(name_datas[name])] = row

        
for name, df in name_datas.items():
    for index, row in df.iterrows():
        # if row['Result'] == '성공':
        #     if row['Level'] == 0:
        #         df.at[index, 'Sword_name'] = None
        #     prev_sword = df.loc[index - 1, 'Sword_name'] if index > 0 else None
        #     if pd.notna(prev_sword):
        #         df.at[index, 'Sword_name'] = prev_sword
        if row['Result'] == '파괴':
            prev_level = df.loc[index - 1, 'Level'] if index > 0 else None
            prev_sword = df.loc[index - 1, 'Sword_name'] if index > 0 else None
            print(prev_level, prev_sword)
            if pd.notna(prev_level):
                df.at[index, 'Level'] = prev_level
            if pd.notna(prev_sword):
                df.at[index, 'Sword_name'] = prev_sword

    df.to_csv(f'data/{name}.csv', index=False)
    print(f'Saved data for {name} to data/{name}.csv')
# Out:
# 5.0 심연의 낡은 몽둥이
# 4.0 모든 것을 잠식하는 검
# 5.0 정제된 불꽃 검
# 7.0 피의 군주 검
# 9.0 천공의 심장 검
# 10.0 끓고 얼고 울부짖는 주전자
# 8.0 독성 꽃가루를 퍼뜨리는 꽃다발
# 6.0 섬광 파동 몽둥이
# 5.0 썩은 냄새를 풍기는 꽃다발
# 7.0 작열하는 태양의 검
# 4.0 정신을 갉아먹는 넝쿨 몽둥이
# 3.0 자신을 찢어내는 강철심 검
# 3.0 붕괴하는 비전 몽둥이
# 3.0 폭주하는 바람의 검
# 6.0 정제된 전기의 검
# 4.0 잠식하는 대지의 몽둥이
# 7.0 응축된 강철 검
# 5.0 존재를 지워버리는 침묵
# 10.0 창세의 빙하 몽둥이
# 5.0 특이점의 몽둥이
# 3.0 형체를 왜곡하는 그림자 몽둥이
# 6.0 심연의 그림자 검
# 3.0 통제불능의 작열하는 검
# 10.0 진공의 오케스트라 검
# 7.0 중력 강철 검
# 5.0 자아를 삼키는 달빛 검
# 6.0 격동하는 혼돈 검
# 5.0 날아오르는 먼지의 빗자루
# 6.0 조율된 전압 검
# 3.0 침식하는 몽둥이
# 5.0 지혜의 실마리를 쥔 몽둥이
# 6.0 지독한 잔향 폭발 핫도그
# 4.0 존재를 소거하는 공허의 검
# 7.0 뇌전의 검
# 7.0 태양의 불꽃 검
# 4.0 자멸하는 맹독의 몽둥이
# 6.0 정제된 불꽃 검
# 3.0 신체를 마모시키는 몽둥이
# 3.0 시공 붕괴의 검
# 13.0 부처가 걸었던 열반의 신발
# 5.0 존재를 삼키는 어둠의 검
# 8.0 압궤의 중력 검
# 3.0 폭주하는 검
# 5.0 굳건한 대지 검
# 3.0 공허의 붕괴 몽둥이
# 5.0 자신을 태우는 화염 검
# 5.0 굳건한 대지 검
# 3.0 잠식하는 어둠 검
# 7.0 만물을 짓누르는 대지 검
# 7.0 막힌 구멍이 공명을 일으키는 단소
# 8.0 태양의 심장 검
# 5.0 굳건한 강철 몽둥이
# 5.0 응축된 혼돈 검
# 4.0 자신마저 부패시키는 역병의 몽둥이
# 5.0 생명력을 조율하는 검
# 7.0 영혼을 사로잡는 매혹의 몽둥이
# 7.0 짧은 칼날이 광선 단검이 된 광선검
# 4.0 심연의 낡은 몽둥이
# 4.0 광포한 격정의 몽둥이
# 4.0 영혼 포식의 검
# 7.0 영혼의 공명 검
# 7.0 공허의 파동 몽둥이
# 4.0 자신을 붕괴시키는 몽둥이
# 12.0 세크메트의 핏빛 광란 검
# 5.0 몽환을 인도하는 검
# 4.0 포식하는 생명의 검
# 7.0 특이점 중력 몽둥이
# 7.0 인력의 달 검
# 8.0 공허의 근원 몽둥이
# 2.0 현기증 나는 질주의 몽둥이
# 4.0 현실을 조롱하는 환상의 검
# 10.0 불굴의 창세 중력 몽둥이
# 9.0 태초의 폭풍우 검
# 8.0 탁한 색이 암흑을 삼키는 광선검
# 7.0 서릿날 한기 몽둥이
# 5.0 숲의 숨결 넝쿨 몽둥이
# 7.0 절정의 선율 몽둥이
# 5.0 숲의 심장을 품은 검
# 3.0 과부하된 전류 검
# 9.0 업보의 섭리 검
# 6.0 진동하는 대지 검
# 5.0 찰나를 붙잡는 질주의 몽둥이
# 6.0 연정을 엮는 매혹의 몽둥이
# 6.0 굳건한 대지 검
# 8.0 중력의 특이점 검
# 6.0 어둠을 길들인 그림자 몽둥이
# 6.0 정제된 불꽃 검
# 5.0 특이점의 몽둥이
# 4.0 주인을 삼키는 격정의 몽둥이
# 5.0 정제된 불꽃 검
# 4.0 내파하는 검
# 4.0 잠식하는 어둠 검
# 9.0 무
# 6.0 지각변동의 검
# 6.0 운명의 줄기를 쥔 검
# 7.0 맹렬한 전압 검
# 6.0 부러진 파편이 날카로운 빗자루
# 4.0 스스로를 소각하는 눈먼 검
# 4.0 자기파괴적인 강철심 검
# 5.0 생명을 잠식하는 검
# 5.0 가시처럼 날카로운 파편 젓가락
# 6.0 고요한 심해의 검
# 5.0 공명하는 정적의 검
# 5.0 금 간 틈으로 음파를 쏘는 단소
# 5.0 악취가 무기가 된 슬리퍼
# 7.0 절멸의 역병 몽둥이
# 6.0 심연의 속삭임 몽둥이
# 5.0 붕괴하는 전압 검
# 8.0 공허의 소용돌이 몽둥이
# 2.0 지식에 잠식된 몽둥이
# 6.0 응축된 부패 검
# 4.0 존재를 비트는 혼돈의 검
# 5.0 자아를 지우는 폭풍 몽둥이
# 6.0 심연의 침묵 검
# 3.0 모든 소리를 집어삼키는 검
# 8.0 운명을 엮는 매혹의 몽둥이
# 5.0 맹렬히 폭발하는 핫도그
# 3.0 통제 불능의 바람 검
# 3.0 형체를 왜곡하는 그림자 몽둥이
# 7.0 태양의 불꽃 검
# 5.0 자아를 지우는 폭풍 몽둥이
# 4.0 주인을 삼키는 격정의 몽둥이
# 6.0 심연의 그림자 검
# 5.0 자신을 불태우는 태양의 검
# 7.0 시간의 지휘자 검
# 4.0 존재를 지워버리는 침묵
# 8.0 근원의 어둠 검
# 7.0 경계를 허무는 꿈의 검
# 6.0 생명력의 흐름 몽둥이
# 6.0 억제된 비전 몽둥이
# 4.0 자아를 잠식하는 혼돈의 막대
# 2.0 절대 끓지 않는 주전자
# 4.0 주인을 삼키는 격정의 몽둥이
# 7.0 심연의 침묵 검
# 7.0 심연의 침묵 검
# 4.0 폭주하는 소스 핫도그
# 5.0 피를 흩뿌리는 강철 몽둥이
# 5.0 찰나를 붙잡는 질주의 몽둥이
# 6.0 여명의 길잡이 검
# 6.0 지독한 잔향 폭발 핫도그
# 7.0 영혼의 융합 검
# 6.0 징벌의 맹세 검
# 9.0 진홍빛 생명 검
# 8.0 영원을 새기는 매혹의 몽둥이
# 4.0 침식하는 몽둥이
# 6.0 정제된 불꽃 검
# 7.0 심연의 그림자 검
# 9.0 창조의 비전 몽둥이
# 10.0 신들의 휴식을 위한 슬리퍼
# 12.0 스카하의 심연군림 검
# 9.0 창세의 불꽃 검
# 4.0 자기파괴적인 강철심 검
# 6.0 조율된 전압 검
# 5.0 운명의 흐름에 잠식된 검
# 10.0 낭만과 죽음이 피어난 꽃다발
# 4.0 잠식하는 혼령 몽둥이
# 5.0 어둠을 길들인 그림자 몽둥이
# 10.0 사방을 베고 찌르는 병기 우산
# 5.0 영혼을 다스리는 몽둥이
# 11.0 라의 신성한 태양 검
# 9.0 영원의 빙결 몽둥이
# 8.0 자연의 섭리 몽둥이
# 6.0 푸른 불꽃 검
# 4.0 존재를 소멸시키는 혼돈 검
# 7.0 태양의 불꽃 검
# 6.0 폭풍의 눈 검
# 5.0 찰나의 궤적 몽둥이
# 3.0 역류하는 검
# 5.0 존재를 지우는 비전 몽둥이
# 5.0 기름때 범벅의 젓가락
# 1.0 불협화음의 검
# 7.0 심연의 그림자 검
# 4.0 형체를 붕괴시키는 몽둥이
# 10.0 현실을 창조하는 몽환의 검
# 7.0 격렬한 분노의 몽둥이
# 6.0 숭고한 빛의 몽둥이
# 6.0 응축된 혼돈 검
# 5.0 저주받은 듯 불편한 슬리퍼
# 4.0 스스로를 찢어버리는 몽둥이
# 8.0 냉기를 뿜어내는 역설의 주전자
# 6.0 지혜의 정수 몽둥이
# 6.0 심판의 단죄 검
# 3.0 붕괴하는 시간의 몽둥이
# 8.0 천상의 광휘 몽둥이
# 3.0 독기로 뒤틀린 몽둥이
# Saved data for 하민수 to data/하민수.csv
# 2.0 부패하는 역병의 몽둥이
# 3.0 통제불능의 작열하는 검
# 6.0 시간을 새기는 검
# 7.0 응축된 혼돈의 막대
# 9.0 진홍빛 생명 검
# 9.0 망각의 그림자 검
# 6.0 찰나의 궤적 몽둥이
# 8.0 잔향 지배자 핫도그
# 6.0 유도 폭발 핫도그
# 5.0 찢어진 천이 칼날이 된 우산
# 6.0 부러진 파편이 날카로운 빗자루
# 7.0 모든 것을 삼키는 몽둥이
# 8.0 생명의 근원 몽둥이
# 9.0 찬란한 태양 검
# 5.0 응집된 폭풍 몽둥이
# 4.0 썩은 냄새를 풍기는 꽃다발
# 4.0 존재 소멸의 징벌
# 4.0 주인을 석화시키는 암석 검
# 7.0 심연 응축의 검
# 8.0 태초의 침묵 검
# 4.0 특이점의 몽둥이
# 8.0 태초 섭리의 혼돈 검
# 9.0 묵시록의 징벌의 몽둥이
# 9.0 영원월의 검
# 8.0 신성한 율법 검
# 4.0 존재를 지우는 그림자 몽둥이
# 8.0 만물을 꿰뚫는 비전 몽둥이
# 11.0 티아마트의 태초 혼돈 막대
# 5.0 자신을 집어삼키는 바람 검
# 8.0 특이점 중력 몽둥이
# 4.0 주인을 삼키는 격정의 몽둥이
# 12.0 릴리트의 맹약 검
# 9.0 태초의 중력 몽둥이
# 7.0 시간 조작의 검
# 6.0 흑사병의 물결 몽둥이
# 5.0 자아를 지우는 폭풍 몽둥이
# 7.0 현현하는 비전 몽둥이
# 5.0 어둠을 길들인 그림자 몽둥이
# 3.0 뒤틀리는 혼령 몽둥이
# 7.0 시간 조작의 검
# Saved data for 정해영 to data/정해영.csv
# 8.0 생명의 근원 검
# 4.0 숙주를 붕괴시키는 낡은 몽둥이
# 9.0 영혼 군주의 검
# 5.0 조율된 침묵 검
# 5.0 정제된 침묵의 검
# 5.0 어둠을 길들인 그림자 몽둥이
# 8.0 생명의 핵 검
# 5.0 정신을 갉아먹는 넝쿨 몽둥이
# 6.0 냉철한 한기 몽둥이
# 5.0 조율된 침묵 검
# 4.0 존재를 해체하는 오페라
# 8.0 녹슨 가루를 뿌리는 독성 우산
# 7.0 피의 맹세 검
# 8.0 폭풍의 눈 검
# 4.0 썩은 냄새를 풍기는 꽃다발
# 11.0 세상의 먼지를 정화하는 자
# 10.0 진홍빛 창세의 검
# 2.0 끈적이는 공허 몽둥이
# 12.0 반시의 절규 검
# 7.0 선혈의 지배자 검
# 11.0 야누스 영겁의 문 검
# 5.0 의지를 따르는 광휘의 몽둥이
# 5.0 존재를 좀먹는 생령의 몽둥이
# 5.0 성스러움에 흡수된 성광의 몽둥이
# 8.0 천상의 섭리 몽둥이
# 5.0 지식에 용해된 몽둥이
# 8.0 소멸의 그림자 몽둥이
# 4.0 심연의 검
# 7.0 지독한 악취로 적을 쫓는 빗자루
# 6.0 정제된 불꽃 검
# 5.0 정제된 그림자 검
# 9.0 불타는 손잡이가 화염검이 된 주전자
# 4.0 스스로를 침식하는 불협화음 몽둥이
# 2.0 휘몰아치는 바람의 검
# 3.0 황폐화시키는 넝쿨 몽둥이
# 7.0 근원의 비전 몽둥이
# 5.0 지혜의 정수 몽둥이
# 3.0 공허 소용돌이의 검
# 8.0 군림하는 혼돈의 막대
# 4.0 모든 것을 잠식하는 검
# 4.0 피를 흩뿌리는 강철 몽둥이
# 4.0 존재를 지우는 그림자 몽둥이
# 9.0 창공의 맹약 몽둥이
# 10.0 신화의 리바이어던 검
# 5.0 존재를 지우는 마력 몽둥이
# 7.0 격렬한 분노의 몽둥이
# 5.0 응집된 폭풍 몽둥이
# 4.0 존재를 지워버리는 침묵
# 7.0 영광의 대협주곡 몽둥이
# 5.0 조율된 리듬 몽둥이
# 3.0 생명력을 갉아먹는 뿌리 검
# 4.0 뿌리박는 대지 검
# 8.0 압궤의 중력 검
# 9.0 멸절의 진노 검
# 5.0 응축된 혼돈 검
# 4.0 소멸하는 달 그림자 검
# 6.0 섬광추격의 몽둥이
# 6.0 현현한 영혼의 몽둥이
# 7.0 태양의 심장 검
# 10.0 만상의 화음 검
# 8.0 영혼 율법의 검
# 5.0 자아를 잠식하는 애착의 몽둥이
# 6.0 단죄의 칼날 검
# 3.0 공허 소용돌이의 검
# 10.0 신화의 음유시 검
# 8.0 섭리의 흐름을 다스리는 검
# 5.0 스스로를 찢어버리는 몽둥이
# 9.0 영원의 빙결 몽둥이
# 5.0 저주받은 듯 불길한 빗자루
# 10.0 시공간 지배 몽둥이
# 9.0 세상의 오염을 휘두르는 빗자루
# 5.0 물이 새는 저주받은 우산
# 6.0 폭풍의 눈 검
# 6.0 정제된 침묵의 검
# 10.0 창세의 빙하 몽둥이
# Saved data for 이준엽 to data/이준엽.csv
# 6.0 통제된 맹독의 검
# 4.0 병적인 애착의 몽둥이
# 4.0 독기로 뒤틀린 몽둥이
# 4.0 공허의 존재말소 몽둥이
# 6.0 정제된 불꽃 검
# 9.0 근원을 창조하는 비전 몽둥이
# 7.0 서릿날 한기 몽둥이
# 5.0 응축된 혼돈의 검
# 4.0 스스로를 찢어발기는 검
# 10.0 창세의 심연 검
# 11.0 신화의 거신 티탄 검
# 3.0 이성을 집어삼키는 몽둥이
# 9.0 잔향 지배자 핫도그
# 7.0 환상을 엮는 검
# 8.0 심연을 홀리는 매혹의 몽둥이
# Saved data for 정인영 to data/정인영.csv
# 5.0 윙 소리가 안 나는 광선검
# 4.0 존재를 잠식하는 그림자 검
# 5.0 자아를 삼키는 비전 몽둥이
# 4.0 존재를 해체하는 오페라
# 3.0 잠식하는 수풀 검
# 10.0 창세의 태양 검
# 6.0 깜빡임이 섬광이 된 광선검
# 5.0 여명의 길잡이 검
# 5.0 자아를 삼키는 달빛 검
# 4.0 파열하는 음파의 리듬 몽둥이
# 6.0 창궐하는 역병의 몽둥이
# 8.0 심연의 부패 몽둥이
# 4.0 생명을 잠식하는 검
# 4.0 자신을 파쇄하는 강철심 검
# 5.0 물이 새는 저주받은 우산
# 10.0 창조의 율동 검
# 6.0 성결한 축복의 검
# 7.0 해일의 힘 검
# 5.0 억제된 광기의 몽둥이
# 6.0 심연의 응축 몽둥이
# 4.0 모든 것을 잠식하는 검
# 7.0 독성 꽃가루를 퍼뜨리는 꽃다발
# 4.0 존재를 지우는 어둠 검
# 4.0 주인을 석화시키는 암석 검
# 4.0 주인을 삼키는 격정의 몽둥이
# 9.0 만상의 화음 검
# 11.0 신들의 휴식을 위한 슬리퍼
# 7.0 특이점 중력 몽둥이
# 7.0 최후의 심판 검
# 9.0 생명의 근원 몽둥이
# 7.0 절멸의 분노 몽둥이
# 3.0 동상 걸린 몽둥이
# 3.0 모든 것을 잠식하는 낡은 몽둥이
# 9.0 영원한 대지의 검
# 7.0 중력의 파동 검
# 6.0 뇌전의 검
# 6.0 끓어오르는 분노의 몽둥이
# 9.0 불멸의 불꽃 검
# 9.0 창세의 폭풍 검
# 5.0 형체를 붕괴시키는 몽둥이
# 9.0 만물의 피 검
# 4.0 물이 찬 단소
# 5.0 파열하는 음파의 리듬 몽둥이
# 4.0 지식에 용해된 몽둥이
# 9.0 몽환의 지배자 검
# 6.0 격동하는 혼돈 검
# 5.0 영혼을 사로잡는 매혹의 몽둥이
# 9.0 근원의 어둠 검
# 5.0 맹렬한 징벌의 몽둥이
# 6.0 제어된 혼돈의 막대
# 5.0 제어된 비전 몽둥이
# 4.0 존재 부정의 검
# 5.0 암흑을 품은 그림자 검
# 9.0 공허의 심장 몽둥이
# 10.0 창세의 대지 검
# 8.0 불멸의 분노 몽둥이
# 6.0 징벌의 맹세 검
# 2.0 현기증 나는 질주의 몽둥이
# 4.0 파열하는 몽둥이
# 6.0 뇌전의 검
# 6.0 파쇄 강철 몽둥이
# 4.0 자신을 파쇄하는 강철심 검
# 8.0 세계수의 심장 검
# 4.0 혼을 잠식하는 집착의 몽둥이
# 5.0 깜빡임이 섬광이 된 광선검
# 4.0 자아를 집어삼키는 환상의 검
# 7.0 심판의 단죄 검
# 7.0 섭리의 흐름을 지휘하는 검
# 7.0 진리의 계시 몽둥이
# 5.0 존재를 잠식하는 그림자 검
# 6.0 심연을 가르는 그림자 검
# 8.0 섭리의 영원한 율법 검
# Saved data for 김동혁 to data/김동혁.csv
# 2.0 왜곡된 비전 몽둥이
# 6.0 회오리바람 검
# 5.0 정제된 그림자 검
# 6.0 조율된 달빛 검
# 3.0 잠식하는 대지의 몽둥이
# 6.0 율동하는 생령의 몽둥이
# 12.0 루시퍼의 지배하는 광휘 몽둥이
# 4.0 자신을 태우는 화염 검
# 5.0 고요한 달그림자 검
# 4.0 모든 것을 잠식하는 검
# 5.0 주인을 삼키는 격정의 몽둥이
# 10.0 창세의 혼돈의 막대
# 8.0 천상월의 검
# 4.0 폭주하는 바람의 검
# 13.0 풍백의 천지권능
# 6.0 서릿날 한기 몽둥이
# 4.0 자아 소멸의 달그림자 검
# 3.0 영혼을 갉아먹는 소음 몽둥이
# 9.0 창세의 그림자 검
# 8.0 자연의 섭리 몽둥이
# 4.0 자신을 지워버리는 광휘의 몽둥이
# 5.0 제어된 맹돌의 몽둥이
# 5.0 물줄기가 채찍이 된 주전자
# 5.0 암흑을 품은 그림자 검
# 4.0 존재 부정의 검
# 7.0 섬광추격의 몽둥이
# 8.0 찬란한 태양 검
# 5.0 파열하는 음파의 리듬 몽둥이
# 5.0 온기를 삼키는 몽둥이
# 4.0 주인의 피를 말리는 검
# 9.0 절대의 그림자 검
# Saved data for 이용준 to data/이용준.csv
# 6.0 징벌의 맹세 검
# 3.0 형체를 뭉개는 검
# 4.0 존재를 흐리는 질주의 몽둥이
# 5.0 고요한 달그림자 검
# 9.0 태초의 바다 몽둥이
# 5.0 심연의 검
# 3.0 손잡이가 부러진 우산
# 5.0 조율된 전압 검
# 8.0 우주의 율려 검
# 4.0 소멸하는 달 그림자 검
# 4.0 영혼마저 집어삼키는 몽둥이
# 5.0 지혜의 존재를 부정하는 몽둥이
# 5.0 섭리의 흐름을 다루는 검
# 2.0 탐식하는 검
# 7.0 중력의 파동 검
# 4.0 스스로를 찢어버리는 몽둥이
# 11.0 원초적 악의 그림자 몽둥이
# 2.0 속박된 운명의 검
# 4.0 자아를 집어삼키는 환상의 검
# 10.0 오르페우스의 신화적 공명 몽둥이
# 10.0 윤회의 영혼 몽둥이
# 7.0 해일의 힘 검
# 7.0 모든 것을 삼키는 검
# 6.0 심연의 속삭임 몽둥이
# 4.0 스스로를 침식하는 불협화음 몽둥이
# 8.0 불멸의 불꽃 검
# Saved data for 최세민 to data/최세민.csv
# 7.0 절멸의 역병 몽둥이
# 8.0 불굴의 강철 검
# 5.0 영혼을 부패시키는 검
# 9.0 진홍빛 창세의 검
# 5.0 섭리의 꼭두각시가 된 검
# 7.0 대자연의 숨결 검
# 9.0 공허의 근원 몽둥이
# 3.0 곰팡이가 핀 칫솔
# 11.0 에덴의 화염검
# 5.0 자아를 잠식하는 애착의 몽둥이
# 5.0 내파하는 검
# 6.0 숭고한 빛의 몽둥이
# 6.0 천상의 계시 몽둥이
# 7.0 뒤집힌 살이 창처럼 튀어나온 우산
# 6.0 통제된 맹독의 검
# 7.0 여명의 태양 검도 이 정도라도 된 거지
# 3.0 소멸하는 검
# 7.0 태양의 심장 검
# 3.0 성스러움에 잠식되는 성광의 몽둥이
# 8.0 독성 꽃가루를 퍼뜨리는 꽃다발
# 7.0 무
# 6.0 제어된 혼돈의 막대
# 5.0 자아를 잠식하는 혼돈의 막대
# 2.0 경직된 몽둥이
# 3.0 잠식하는 그림자 검
# 7.0 맹렬한 혼돈 검
# 6.0 떠오르는 태양의 검
# 5.0 정제된 불꽃 검
# 7.0 환상을 엮는 검
# 11.0 신화강림 칼리의 재앙검
# 4.0 자아를 지우는 폭풍 몽둥이
# 6.0 응축된 그림자 몽둥이
# 5.0 존재 부정의 검
# 9.0 묵시록의 징벌의 몽둥이
# 8.0 혼돈을 집어삼키는 검
# 3.0 병적인 애착의 몽둥이
# 5.0 제어된 맹독의 몽둥이
# 5.0 응축된 그림자 몽둥이
# 9.0 태초 섭리의 혼돈 검
# 13.0 전능한 사마엘의 심판 몽둥이
# Saved data for 지섭 to data/지섭.csv
# 10.0 아르테미스 순결의 사냥 검
# Saved data for 차민규 to data/차민규.csv

# %%
level_datas = {}

for _, df in name_datas.items():
    for _, row in df.iterrows():
        level = row['Level']
        result = row['Result']
        if level not in level_datas:
            level_datas[level] = {'성공': 0, '유지': 0, '파괴': 0}
        level_datas[level][result] += 1

for level, results in level_datas.items():
    total = sum(results.values())
    for result, count in results.items():
        rate = (count / total) * 100 if total > 0 else 0
        results[result] = rate
    results["Count"] = total

level_summary = pd.DataFrame.from_dict(level_datas, orient='index')
level_summary.index.name = 'Level'
level_summary = level_summary.sort_index()
level_summary.to_csv('level_summary.csv')
print('Saved level summary to level_summary.csv')
# Out:
# Saved level summary to level_summary.csv
